# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd "/content/gdrive/MyDrive/PerfPred/Experiment/lang2vec"
# !apt install python3.10-venv
# !python3 -m build
# Out:
# /content/gdrive/.shortcut-targets-by-id/1vr6Z8seuUA0zoWaHuosCSZMv_H2Go5KR/PerfPred/Experiment/lang2vec
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   python3-pip-whl python3-setuptools-whl
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 16 not upgraded.
# Need to get 2,473 kB of archives.
# After this operation, 2,882 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.3 [1,679 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-setuptools-whl all 59.6.0-1.2ubuntu0.22.04.1 [788 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.2 [5,724 B]
# Fetched 2,473 kB in 1s (2,740 kB/s)
# Selecting previously unselected package python3-pip-whl.
# (Reading database ... 120831 files and directories currently installed.)
# Preparing to unpack .../python3-pip-whl_22.0.2+dfsg-1ubuntu0.3_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../python3-setuptools-whl_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../python3.10-venv_3.10.12-1~22.04.2_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.2) ...
# Setting up python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.3) ...
# Setting up python3.10-venv (3.10.12-1~22.04.2) ...
# * Creating venv isolated environment...
# * Installing packages in isolated environment... (setuptools >= 40.8.0, wheel)
# * Getting build dependencies for sdist...
# running egg_info
# writing lang2vec.egg-info/PKG-INFO
# writing dependency_links to lang2vec.egg-info/dependency_links.txt
# writing requirements to lang2vec.egg-info/requires.txt
# writing top-level names to lang2vec.egg-info/top_level.txt
# reading manifest file 'lang2vec.egg-info/SOURCES.txt'
# adding license file 'LICENSE.txt'
# writing manifest file 'lang2vec.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing lang2vec.egg-info/PKG-INFO
# writing dependency_links to lang2vec.egg-info/dependency_links.txt
# writing requirements to lang2vec.egg-info/requires.txt
# writing top-level names to lang2vec.egg-info/top_level.txt
# reading manifest file 'lang2vec.egg-info/SOURCES.txt'
# adding license file 'LICENSE.txt'
# writing manifest file 'lang2vec.egg-info/SOURCES.txt'
# running check
# creating lang2vec-1.1.6
# creating lang2vec-1.1.6/lang2vec
# creating lang2vec-1.1.6/lang2vec.egg-info
# creating lang2vec-1.1.6/lang2vec/data
# copying files to lang2vec-1.1.6...
# copying LICENSE.txt -> lang2vec-1.1.6
# copying README.md -> lang2vec-1.1.6
# copying setup.py -> lang2vec-1.1.6
# copying lang2vec/__init__.py -> lang2vec-1.1.6/lang2vec
# copying lang2vec/lang2vec.py -> lang2vec-1.1.6/lang2vec
# copying lang2vec.egg-info/PKG-INFO -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/PKG-INFO (1) -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/PKG-INFO (2) -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/PKG-INFO (3) -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/SOURCES (1).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/SOURCES (2).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/SOURCES (3).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/SOURCES.txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/dependency_links (1).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/dependency_links (2).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/dependency_links (3).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/dependency_links.txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/requires (1).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/requires (2).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/requires (3).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/requires.txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/top_level (1).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/top_level (2).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/top_level (3).txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/top_level.txt -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec.egg-info/zip-safe -> lang2vec-1.1.6/lang2vec.egg-info
# copying lang2vec/data/distances2.zip -> lang2vec-1.1.6/lang2vec/data
# copying lang2vec/data/distances_languages.txt -> lang2vec-1.1.6/lang2vec/data
# copying lang2vec/data/family_features.npz -> lang2vec-1.1.6/lang2vec/data
# copying lang2vec/data/feature_averages.npz -> lang2vec-1.1.6/lang2vec/data
# copying lang2vec/data/feature_predictions.npz -> lang2vec-1.1.6/lang2vec/data
# copying lang2vec/data/features.npz -> lang2vec-1.1.6/lang2vec/data
# copying lang2vec/data/geocoord_features.npz -> lang2vec-1.1.6/lang2vec/data
# copying lang2vec/data/learned.npy -> lang2vec-1.1.6/lang2vec/data
# copying lang2vec/data/letter_codes.json -> lang2vec-1.1.6/lang2vec/data
# Writing lang2vec-1.1.6/setup.cfg
# Creating tar archive
# removing 'lang2vec-1.1.6' (and everything under it)
# * Building wheel from sdist
# * Creating venv isolated environment...
# * Installing packages in isolated environment... (setuptools >= 40.8.0, wheel)
# * Getting build dependencies for wheel...
# running egg_info
# writing lang2vec.egg-info/PKG-INFO
# writing dependency_links to lang2vec.egg-info/dependency_links.txt
# writing requirements to lang2vec.egg-info/requires.txt
# writing top-level names to lang2vec.egg-info/top_level.txt
# reading manifest file 'lang2vec.egg-info/SOURCES.txt'
# adding license file 'LICENSE.txt'
# writing manifest file 'lang2vec.egg-info/SOURCES.txt'
# * Installing packages in isolated environment... (wheel)
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/lang2vec
# copying lang2vec/__init__.py -> build/lib/lang2vec
# copying lang2vec/lang2vec.py -> build/lib/lang2vec
# creating build/lib/lang2vec/data
# copying lang2vec/data/features.npz -> build/lib/lang2vec/data
# copying lang2vec/data/geocoord_features.npz -> build/lib/lang2vec/data
# copying lang2vec/data/family_features.npz -> build/lib/lang2vec/data
# copying lang2vec/data/feature_averages.npz -> build/lib/lang2vec/data
# copying lang2vec/data/feature_predictions.npz -> build/lib/lang2vec/data
# copying lang2vec/data/letter_codes.json -> build/lib/lang2vec/data
# copying lang2vec/data/distances2.zip -> build/lib/lang2vec/data
# copying lang2vec/data/learned.npy -> build/lib/lang2vec/data
# copying lang2vec/data/distances_languages.txt -> build/lib/lang2vec/data
# running build_scripts
# creating build/scripts-3.10
# copying and adjusting lang2vec/lang2vec.py -> build/scripts-3.10
# changing mode of build/scripts-3.10/lang2vec.py from 644 to 755
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/lang2vec
# creating build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/data/distances_languages.txt -> build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/data/features.npz -> build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/data/distances2.zip -> build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/data/geocoord_features.npz -> build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/data/family_features.npz -> build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/data/learned.npy -> build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/data/feature_averages.npz -> build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/data/feature_predictions.npz -> build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/data/letter_codes.json -> build/bdist.linux-x86_64/wheel/lang2vec/data
# copying build/lib/lang2vec/__init__.py -> build/bdist.linux-x86_64/wheel/lang2vec
# copying build/lib/lang2vec/lang2vec.py -> build/bdist.linux-x86_64/wheel/lang2vec
# running install_egg_info
# running egg_info
# writing lang2vec.egg-info/PKG-INFO
# writing dependency_links to lang2vec.egg-info/dependency_links.txt
# writing requirements to lang2vec.egg-info/requires.txt
# writing top-level names to lang2vec.egg-info/top_level.txt
# reading manifest file 'lang2vec.egg-info/SOURCES.txt'
# adding license file 'LICENSE.txt'
# writing manifest file 'lang2vec.egg-info/SOURCES.txt'
# Copying lang2vec.egg-info to build/bdist.linux-x86_64/wheel/lang2vec-1.1.6-py3.10.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/lang2vec-1.1.6.data
# creating build/bdist.linux-x86_64/wheel/lang2vec-1.1.6.data/scripts
# copying build/scripts-3.10/lang2vec.py -> build/bdist.linux-x86_64/wheel/lang2vec-1.1.6.data/scripts
# changing mode of build/bdist.linux-x86_64/wheel/lang2vec-1.1.6.data/scripts/lang2vec.py to 755
# creating build/bdist.linux-x86_64/wheel/lang2vec-1.1.6.dist-info/WHEEL
# creating '/content/gdrive/.shortcut-targets-by-id/1vr6Z8seuUA0zoWaHuosCSZMv_H2Go5KR/PerfPred/Experiment/lang2vec/dist/.tmp-gl49c5bk/lang2vec-1.1.6-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'lang2vec/__init__.py'
# adding 'lang2vec/lang2vec.py'
# adding 'lang2vec/data/distances2.zip'
# adding 'lang2vec/data/distances_languages.txt'
# adding 'lang2vec/data/family_features.npz'
# adding 'lang2vec/data/feature_averages.npz'
# adding 'lang2vec/data/feature_predictions.npz'
# adding 'lang2vec/data/features.npz'
# adding 'lang2vec/data/geocoord_features.npz'
# adding 'lang2vec/data/learned.npy'
# adding 'lang2vec/data/letter_codes.json'
# adding 'lang2vec-1.1.6.data/scripts/lang2vec.py'
# adding 'lang2vec-1.1.6.dist-info/LICENSE.txt'
# adding 'lang2vec-1.1.6.dist-info/METADATA'
# adding 'lang2vec-1.1.6.dist-info/PKG-INFO (1)'
# adding 'lang2vec-1.1.6.dist-info/PKG-INFO (2)'
# adding 'lang2vec-1.1.6.dist-info/PKG-INFO (3)'
# adding 'lang2vec-1.1.6.dist-info/SOURCES (1).txt'
# adding 'lang2vec-1.1.6.dist-info/SOURCES (2).txt'
# adding 'lang2vec-1.1.6.dist-info/SOURCES (3).txt'
# adding 'lang2vec-1.1.6.dist-info/WHEEL'
# adding 'lang2vec-1.1.6.dist-info/dependency_links (1).txt'
# adding 'lang2vec-1.1.6.dist-info/dependency_links (2).txt'
# adding 'lang2vec-1.1.6.dist-info/dependency_links (3).txt'
# adding 'lang2vec-1.1.6.dist-info/requires (1).txt'
# adding 'lang2vec-1.1.6.dist-info/requires (2).txt'
# adding 'lang2vec-1.1.6.dist-info/requires (3).txt'
# adding 'lang2vec-1.1.6.dist-info/top_level (1).txt'
# adding 'lang2vec-1.1.6.dist-info/top_level (2).txt'
# adding 'lang2vec-1.1.6.dist-info/top_level (3).txt'
# adding 'lang2vec-1.1.6.dist-info/top_level.txt'
# adding 'lang2vec-1.1.6.dist-info/zip-safe'
# adding 'lang2vec-1.1.6.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built lang2vec-1.1.6.tar.gz and lang2vec-1.1.6-py3-none-any.whl

# %%
from google.colab import auth
from google.auth import default
import gspread as gs
import gspread_dataframe as gsdf
import lang2vec.lang2vec as l2v
import numpy as np
from numpy.linalg import norm
import pandas as pd
from scipy.spatial import distance
from sklearn.preprocessing import normalize

# %%
auth.authenticate_user()
creds, _ = default()
gc = gs.authorize(creds)

# %%
def write_to_sheet(df: pd.DataFrame, sh: gs.Spreadsheet, name: str=None, index: bool=True) -> None:
  try:
    try:
      if name is None:
        wsh = sh.get_worksheet(0)
      else:
        wsh = sh.worksheet(name)
    except gs.exceptions.WorksheetNotFound:
      wsh = sh.get_worksheet(0).duplicate(insert_sheet_index=len(sh.worksheets()), new_sheet_name=name)
    gsdf.set_with_dataframe(wsh, df, include_index=index, include_column_header=True, resize=True)
    if name is not None:
      wsh.update_title(name)
    # print(f"Wrote to {sh.title}:{name}.")
  except gs.exceptions.APIError:
    print("Sleeping for 60 seconds...", file=sys.stderr)
    time.sleep(60)
    write_to_sheet(df, sh, name, index)

# %% [markdown]
# # Features

# %% [markdown]
# ## General Stuff

# %%
feat_sheet = gc.open('l2v features')

# %%
hrls = ["eng", "fra"]
lrls = ['kan', 'guj', 'hin', 'sin', 'tam']
# hope = ["afr", "xho", "gle", "yor", "asm"]
all_langs = hrls + lrls + hope

# %%
uriel, learned, all = l2v.URIEL_LANGUAGES, l2v.LEARNED_LANGUAGES, l2v.LANGUAGES
print("# of URIEL languages:", len(uriel))
print("# of learned languages:", len(learned))
print("# of all languages:", len(all)) # same as union of uriel & learned
print("# of languages in both URIEL and learned:", len(set(uriel).intersection(learned)))
# Out:
# # of URIEL languages: 3718
# # of learned languages: 1017
# # of all languages: 4005
# # of languages in both URIEL and learned: 730

# %%
for lang in langs:
  if lang in uriel and lang in learned:
    print(f"{lang} is in uriel and learned.")
  elif lang in uriel:
    print(f"{lang} is in uriel only.")
  elif lang in learned:
    print(f"{lang} is in learned only.")
  else:
    print(f"{lang} is in neither uriel or learned.")
# Out:
# eng is in uriel only.
# fra is in uriel and learned.
# kan is in uriel only.
# guj is in uriel only.
# hin is in uriel and learned.
# sin is in uriel only.
# tam is in uriel and learned.
# afr is in uriel and learned.
# xho is in uriel and learned.
# gle is in uriel and learned.
# yor is in uriel and learned.
# asm is in uriel only.

# %%
all_feats = l2v.FEATURE_SETS
feat_types = ["syntax", "phonology", "inventory", "genetic", "geographic"]
feats_by_type = {}
for ftype in feat_types[0:3]:
  feats_by_type[ftype] = [feat for feat in all_feats if feat.startswith(ftype)]
feats_by_type["genetic"] = ["fam"]
feats_by_type["geographic"] = ["geo"]
all_feats = []
for ftype in feat_types:
  all_feats += feats_by_type[ftype]

# %%
count_df = pd.DataFrame(columns = all_feats, index = ["CODE"] + langs)
for feat in all_feats:
  vals = l2v.get_features(langs, feat, header=True)
  for row in ["CODE"] + langs:
    count_df.loc[row, feat] = len([val for val in vals[row] if val != '--'])

# %%
write_to_sheet(count_df, feat_sheet, "count of filled values", index=True)

# %% [markdown]
# ## Values for ftype and lang

# %%
def english_ftype_vectors(lang, ftype, write=True):
  feats = feats_by_type[ftype]
  code = l2v.get_features(lang, feats[0], header=True)['CODE']
  df = pd.DataFrame(index = code, columns = feats)
  for feat in feats:
    df[feat] = l2v.get_features(lang, feat)[lang]
  if ftype in feat_types[0:3]:
    union = "|".join(feats[:-2])
    df[union] = l2v.get_features(lang, union)[lang]
  df.replace("--", pd.NA, inplace=True)
  df = df.astype("Float64")

  if ftype in feat_types[0:3]:
    basic = df.loc[:, feats[0]:feats[-3]]

    df[f'reproduced {ftype}_average'] = basic.mean(axis=1).round(decimals=4)
    orig, repro = df[f'{ftype}_average'], df[f'reproduced {ftype}_average']
    if not orig.eq(repro, fill_value=-1).all():
      print(f'Failed at reproducing {ftype}_average.')

    df[f'reproduced {union}'] = basic.any(axis=1).astype("Int64")
    df.loc[basic.index[basic.isnull().all(axis=1)], f'reproduced {union}'] = pd.NA
    orig, repro = df[union], df[f'reproduced {union}']
    if not orig.eq(repro, fill_value=-1).all():
      print(f'Failed at reproducing {union}.')

  if write:
    write_to_sheet(df, feat_sheet, f"{lang} {ftype}", index=True)
  return df

# %%
for ftype in feat_types:
  for lang in hrls:
    english_ftype_vectors(lang, ftype)

# %% [markdown]
# # Distances

# %% [markdown]
# ## Pre-Computed

# %%
dist_sheet = gc.open('l2v distances')

# %%
dist_types = ['syntactic', 'phonological', 'inventory', 'featural', 'genetic', 'geographic'] # l2v.DISTANCES but in a different order
dist_by_ftype = {'syntax': 'syntactic', 'phonology': 'phonological', 'inventory': 'inventory', 'genetic': 'genetic', 'geographic': 'geographic'}
all_dists = l2v.distance(dist_types, all_langs)

# %%
dists_df = pd.DataFrame(index = dist_types, columns = all_langs)
for i, dtype in enumerate(dist_types):
  dists_df.loc[dtype] = all_dists[i][0]
write_to_sheet(dists_df, dist_sheet, "distances to english", index=True)

# %% [markdown]
# ## Different Definitions of Distance

# %%
def compare_dists(ftype, funcs):
  feats = feats_by_type[ftype].copy()
  feats += ["|".join(feats[:-2])]

  feat_vals = {}
  for feat in feats:
    vals = l2v.get_features(hrls, feat)
    vals = np.array([vals["eng"], vals["fra"]])
    if vals.dtype != float:
      indices = np.where((vals[0] != "--") & (vals[1] != "--"))[0]
      vals = vals[:, indices].astype(float)
    if len(vals[0]):
      feat_vals[feat] = vals
  feats = feat_vals.keys()

  series = []
  for name, f in funcs.items():
    tmp = []
    for feat in feats:
      x, y = feat_vals[feat][0], feat_vals[feat][1]
      tmp.append(f(x, y))
    series.append(pd.Series(tmp, index=feats, name=name))

  repro_df = pd.DataFrame(series)
  write_to_sheet(repro_df, dist_sheet, f"eng-fra {dist_by_ftype[ftype]}", index=True)
  return repro_df

# %%
funcs = {
    "normalized euclidean": lambda x, y: distance.euclidean(x / norm(x), y / norm(y)),
    "cosine distance": distance.cosine,
    "angular distance": lambda x, y: np.arccos(1 - distance.cosine(x, y)) / np.pi * 2
}

# %%
compare_dists("syntax", funcs)
# Out:
#                       syntax_wals  syntax_sswl  syntax_ethnologue  syntax_knn  \
# normalized euclidean     0.665898     0.591679                0.0    0.613589
# cosine distance          0.221710     0.175042                0.0    0.188246
# angular distance         0.432175     0.382398                0.0    0.397026
#
#                       syntax_average  \
# normalized euclidean        0.627832
# cosine distance             0.197087
# angular distance            0.406564
#
#                       syntax_wals|syntax_sswl|syntax_ethnologue
# normalized euclidean                                   0.648464
# cosine distance                                        0.210253
# angular distance                                       0.420423

# %%
compare_dists("phonology", funcs)

# %%
compare_dists("inventory", funcs)

# %% [markdown]
# ## Distance Using Different Vector Types

# %%
def angular_distance(x, y):
  return 2 / np.pi * np.arccos(round(np.dot(x, y) / (norm(x) * norm(y)), 8))

# %%
def find_dists(ftype, langs):
  feats = feats_by_type[ftype].copy()
  feats += ["|".join(feats[:-2])]

  feat_vals = {}
  for feat in feats:
    feat_vals[feat] = l2v.get_features(langs, feat)

  series = []
  for lang in langs:
    tmp = [dists_df.loc[dist_by_ftype[ftype], lang]]
    for feat in feats:
      x, y = np.array(feat_vals[feat]["eng"]), np.array(feat_vals[feat][lang])
      if x.dtype != float or y.dtype != float:
        x, y = x.astype(str), y.astype(str)
        indices = np.where((x != "--") & (y != "--"))[0]
        x, y = x[indices].astype(float), y[indices].astype(float)
      if len(x) == 0 or norm(x) == 0 or norm(y) == 0:
        tmp.append(pd.NA)
      else:
        tmp.append(angular_distance(x, y))
    series.append(pd.Series(tmp, index=["pre-computed"] + feats, name=f"eng-{lang}"))

  repro_df = pd.DataFrame(series)
  repro_df.fillna("N/A", inplace=True)
  write_to_sheet(repro_df, dist_sheet, dist_by_ftype[ftype], index=True)
  return repro_df

# %%
find_dists("syntax", all_langs)
# Out:
#          pre-computed  syntax_wals syntax_sswl syntax_ethnologue  syntax_knn  \
# eng-eng          0.00     0.000000         0.0               0.0    0.000000
# eng-fra          0.46     0.432175    0.382398               0.0    0.397026
# eng-kan          0.64     0.600141    0.598842          0.666667    0.641843
# eng-guj          0.68     0.460107         N/A               N/A    0.603406
# eng-hin          0.59     0.542846    0.583478           0.73802    0.577346
# eng-sin          0.78     0.579167         N/A          0.666667    0.623076
# eng-tam          0.71     0.651553         N/A          0.666667    0.656687
# eng-afr          0.63     0.000000    0.432694               N/A    0.353934
# eng-xho          0.76     0.694486         N/A               N/A    0.681242
# eng-gle          0.62     0.523086    0.573405          0.666667    0.488225
# eng-yor          0.61     0.605478    0.506242               0.0    0.590096
# eng-asm          0.81     0.706314         N/A               N/A    0.651957
#
#          syntax_average  syntax_wals|syntax_sswl|syntax_ethnologue
# eng-eng        0.000000                                   0.000000
# eng-fra        0.406564                                   0.420423
# eng-kan        0.588709                                   0.595294
# eng-guj        0.483457                                   0.545629
# eng-hin        0.553821                                   0.550821
# eng-sin        0.562551                                   0.595887
# eng-tam        0.651049                                   0.659402
# eng-afr        0.385927                                   0.420707
# eng-xho        0.682634                                   0.682459
# eng-gle        0.498300                                   0.535441
# eng-yor        0.590873                                   0.590334
# eng-asm        0.722092                                   0.737672

# %%
find_dists("phonology", all_langs)
# Out:
#          pre-computed phonology_wals phonology_ethnologue  phonology_knn  \
# eng-eng        0.0000            0.0                  N/A       0.000000
# eng-fra        0.4270       0.457582                  N/A       0.457582
# eng-kan        0.3498       0.349802                  N/A       0.405370
# eng-guj        0.5687            N/A                  N/A       0.405370
# eng-hin        0.3433        0.34327                  N/A       0.427019
# eng-sin        0.4121       0.312506                  N/A       0.447678
# eng-tam        0.5687            N/A                  N/A       0.349802
# eng-afr        0.5687            N/A                  N/A       0.389964
# eng-xho        0.5687            N/A                  N/A       0.349802
# eng-gle        0.5687            N/A                  N/A       0.343270
# eng-yor        0.5348       0.534794                  N/A       0.534794
# eng-asm        0.5687            N/A                  N/A       0.447678
#
#         phonology_average phonology_wals|phonology_ethnologue
# eng-eng               0.0                                 0.0
# eng-fra          0.457582                            0.457582
# eng-kan          0.349802                            0.349802
# eng-guj               N/A                                 N/A
# eng-hin           0.34327                             0.34327
# eng-sin          0.312506                            0.312506
# eng-tam               N/A                                 N/A
# eng-afr               N/A                                 N/A
# eng-xho               N/A                                 N/A
# eng-gle               N/A                                 N/A
# eng-yor          0.534794                            0.534794
# eng-asm               N/A                                 N/A

# %%
find_dists("inventory", all_langs)
# Out:
#          pre-computed inventory_ethnologue inventory_phoible_aa  \
# eng-eng        0.0000                  N/A                  N/A
# eng-fra        0.4753                  N/A                  N/A
# eng-kan        0.4738                  N/A                  N/A
# eng-guj        0.4753                  N/A                  N/A
# eng-hin        0.4684                  N/A                  N/A
# eng-sin        0.4991                  N/A                  N/A
# eng-tam        0.5014                  N/A                  N/A
# eng-afr        0.5144                  N/A                  N/A
# eng-xho        0.5032                  N/A                  N/A
# eng-gle        0.5193                  N/A                  N/A
# eng-yor        0.5093                  N/A                  N/A
# eng-asm        0.4638                  N/A                  N/A
#
#         inventory_phoible_gm inventory_phoible_saphon inventory_phoible_spa  \
# eng-eng                  N/A                      N/A                   0.0
# eng-fra                  N/A                      N/A              0.486128
# eng-kan                  N/A                      N/A                   N/A
# eng-guj                  N/A                      N/A                   N/A
# eng-hin                  N/A                      N/A               0.52489
# eng-sin                  N/A                      N/A               0.51421
# eng-tam                  N/A                      N/A                   N/A
# eng-afr                  N/A                      N/A                   N/A
# eng-xho                  N/A                      N/A                   N/A
# eng-gle                  N/A                      N/A               0.51934
# eng-yor                  N/A                      N/A                   N/A
# eng-asm                  N/A                      N/A                   N/A
#
#         inventory_phoible_ph inventory_phoible_ra inventory_phoible_upsid  \
# eng-eng                  N/A                  N/A                     N/A
# eng-fra                  N/A                  N/A                     N/A
# eng-kan                  N/A                  N/A                     N/A
# eng-guj                  N/A                  N/A                     N/A
# eng-hin                  N/A                  N/A                     N/A
# eng-sin                  N/A                  N/A                     N/A
# eng-tam                  N/A                  N/A                     N/A
# eng-afr                  N/A                  N/A                     N/A
# eng-xho                  N/A                  N/A                     N/A
# eng-gle                  N/A                  N/A                     N/A
# eng-yor                  N/A                  N/A                     N/A
# eng-asm                  N/A                  N/A                     N/A
#
#          inventory_knn  inventory_average  \
# eng-eng       0.000000           0.000000
# eng-fra       0.468829           0.473073
# eng-kan       0.473801           0.473801
# eng-guj       0.475325           0.475325
# eng-hin       0.498211           0.445222
# eng-sin       0.499138           0.496054
# eng-tam       0.542794           0.508792
# eng-afr       0.514399           0.514399
# eng-xho       0.503215           0.503215
# eng-gle       0.512168           0.500358
# eng-yor       0.500496           0.499271
# eng-asm       0.463750           0.463750
#
#          inventory_ethnologue|inventory_phoible_aa|inventory_phoible_gm|inventory_phoible_saphon|inventory_phoible_spa|inventory_phoible_ph|inventory_phoible_ra|inventory_phoible_upsid
# eng-eng                                           0.000000
# eng-fra                                           0.475325
# eng-kan                                           0.473801
# eng-guj                                           0.475325
# eng-hin                                           0.468365
# eng-sin                                           0.499138
# eng-tam                                           0.501389
# eng-afr                                           0.514399
# eng-xho                                           0.503215
# eng-gle                                           0.519340
# eng-yor                                           0.509326
# eng-asm                                           0.463750
